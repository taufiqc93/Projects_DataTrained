# %% [markdown]
# ## Baseball

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve,roc_auc_score
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import PowerTransformer
from scipy.stats import skew

# %%
#imorting dataset
df=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
# renaming the columns
df.rename(columns={'W':'Predicted Wins','R':'Runs','AB':'At Bats','H':'Hits','2B':'Doubles','3B':'Triples','HR':'Homeruns','BB':'Walks','SO':'Strikeouts','SB':'Stolen Bases','RA':'Runs Allowed','ER':'Earned Runs','ERA':'Earned Run Average', 'CG':'Compelete Games','SHO':'Shutouts','SV':'Saves', 'E':'Error'},inplace=True)

# %%
df
# Out:
#     Predicted Wins  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  \
# 0               95   724     5575  1497      300       42       139    383
# 1               83   696     5467  1349      277       44       156    439
# 2               81   669     5439  1395      303       29       141    533
# 3               76   622     5533  1381      260       27       136    404
# 4               74   689     5605  1515      289       49       151    455
# 5               93   891     5509  1480      308       17       232    570
# 6               87   764     5567  1397      272       19       212    554
# 7               81   713     5485  1370      246       20       217    418
# 8               80   644     5485  1383      278       32       167    436
# 9               78   748     5640  1495      294       33       161    478
# 10              88   751     5511  1419      279       32       172    503
# 11              86   729     5459  1363      278       26       230    486
# 12              85   661     5417  1331      243       21       176    435
# 13              76   656     5544  1379      262       22       198    478
# 14              68   694     5600  1405      277       46       146    475
# 15             100   647     5484  1386      288       39       137    506
# 16              98   697     5631  1462      292       27       140    461
# 17              97   689     5491  1341      272       30       171    567
# 18              68   655     5480  1378      274       34       145    412
# 19              64   640     5571  1382      257       27       167    496
# 20              90   683     5527  1351      295       17       177    488
# 21              83   703     5428  1363      265       13       177    539
# 22              71   613     5463  1420      236       40       120    375
# 23              67   573     5420  1361      251       18       100    471
# 24              63   626     5529  1374      272       37       130    387
# 25              92   667     5385  1346      263       26       187    563
# 26              84   696     5565  1486      288       39       136    457
# 27              79   720     5649  1494      289       48       154    490
# 28              74   650     5457  1324      260       36       148    426
# 29              68   737     5572  1479      274       49       186    388
#
#     Strikeouts  Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average  \
# 0          973           104           641          601                3.73
# 1         1264            70           700          653                4.07
# 2         1157            86           640          584                3.67
# 3         1231            68           701          643                3.98
# 4         1259            83           803          746                4.64
# 5         1151            88           670          609                3.80
# 6         1227            63           698          652                4.03
# 7         1331            44           693          646                4.05
# 8         1310            87           642          604                3.74
# 9         1148            71           753          694                4.31
# 10        1233           101           733          680                4.24
# 11        1392           121           618          572                3.57
# 12        1150            52           675          630                3.94
# 13        1336            69           726          677                4.16
# 14        1119            78           729          664                4.14
# 15        1267            69           525          478                2.94
# 16        1322            98           596          532                3.21
# 17        1518            95           608          546                3.36
# 18        1299            84           737          682                4.28
# 19        1255           134           754          700                4.33
# 20        1290            51           613          557                3.43
# 21        1344            57           635          577                3.62
# 22        1150           112           678          638                4.02
# 23        1107            69           760          698                4.41
# 24        1274            88           809          749                4.69
# 25        1258            59           595          553                3.44
# 26        1159            93           627          597                3.72
# 27        1312           132           713          659                4.04
# 28        1327            82           731          655                4.09
# 29        1283            97           844          799                5.04
#
#     Compelete Games  Shutouts  Saves  Error
# 0                 2         8     56     88
# 1                 2        12     45     86
# 2                11        10     38     79
# 3                 7         9     37    101
# 4                 7        12     35     86
# 5                 7        10     34     88
# 6                 3         4     48     93
# 7                 0        10     43     77
# 8                 1        12     60     95
# 9                 3        10     40     97
# 10                5         9     45    119
# 11                5        13     39     85
# 12                2        12     46     93
# 13                6        12     45     94
# 14                5        15     28    126
# 15                1        15     62     96
# 16                0        13     54    122
# 17                6        21     48    111
# 18                1         7     40    116
# 19                2         8     35     90
# 20                1        14     50     88
# 21                4        13     41     90
# 22                0        12     35     77
# 23                3        10     44     90
# 24                1         7     35    117
# 25                6        21     47     75
# 26                7        18     41     78
# 27                1        12     44     86
# 28                1         6     41     92
# 29                4         4     36     95

# %%
df.columns
# Out:
# Index(['Predicted Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples',
#        'Homeruns', 'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed',
#        'Earned Runs', 'Earned Run Average', 'Compelete Games', 'Shutouts',
#        'Saves', 'Error'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Predicted Wins        Runs      At Bats         Hits     Doubles  \
# count       30.000000   30.000000    30.000000    30.000000   30.000000
# mean        80.966667  688.233333  5516.266667  1403.533333  274.733333
# std         10.453455   58.761754    70.467372    57.140923   18.095405
# min         63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%         74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%         81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%         87.750000  718.250000  5570.000000  1451.500000  288.750000
# max        100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs Allowed  Earned Runs  Earned Run Average  Compelete Games  \
# count     30.000000    30.000000           30.000000        30.000000
# mean     688.233333   635.833333            3.956333         3.466667
# std       72.108005    70.140786            0.454089         2.763473
# min      525.000000   478.000000            2.940000         0.000000
# 25%      636.250000   587.250000            3.682500         1.000000
# 50%      695.500000   644.500000            4.025000         3.000000
# 75%      732.500000   679.250000            4.220000         5.750000
# max      844.000000   799.000000            5.040000        11.000000
#
#         Shutouts      Saves       Error
# count  30.000000  30.000000   30.000000
# mean   11.300000  43.066667   94.333333
# std     4.120177   7.869335   13.958889
# min     4.000000  28.000000   75.000000
# 25%     9.000000  37.250000   86.000000
# 50%    12.000000  42.000000   91.000000
# 75%    13.000000  46.750000   96.750000
# max    21.000000  62.000000  126.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Predicted Wins      30 non-null     int64
#  1   Runs                30 non-null     int64
#  2   At Bats             30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Homeruns            30 non-null     int64
#  7   Walks               30 non-null     int64
#  8   Strikeouts          30 non-null     int64
#  9   Stolen Bases        30 non-null     int64
#  10  Runs Allowed        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Compelete Games     30 non-null     int64
#  14  Shutouts            30 non-null     int64
#  15  Saves               30 non-null     int64
#  16  Error               30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Predicted Wins        0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Compelete Games       0
# Shutouts              0
# Saves                 0
# Error                 0
# dtype: int64

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# ## Box Plot

# %%
df.plot(kind='box',subplots=True,layout=(5,4),figsize=(25,25))
# Out:
# Predicted Wins           AxesSubplot(0.125,0.749828;0.168478x0.130172)
# Runs                  AxesSubplot(0.327174,0.749828;0.168478x0.130172)
# At Bats               AxesSubplot(0.529348,0.749828;0.168478x0.130172)
# Hits                  AxesSubplot(0.731522,0.749828;0.168478x0.130172)
# Doubles                  AxesSubplot(0.125,0.593621;0.168478x0.130172)
# Triples               AxesSubplot(0.327174,0.593621;0.168478x0.130172)
# Homeruns              AxesSubplot(0.529348,0.593621;0.168478x0.130172)
# Walks                 AxesSubplot(0.731522,0.593621;0.168478x0.130172)
# Strikeouts               AxesSubplot(0.125,0.437414;0.168478x0.130172)
# Stolen Bases          AxesSubplot(0.327174,0.437414;0.168478x0.130172)
# Runs Allowed          AxesSubplot(0.529348,0.437414;0.168478x0.130172)
# Earned Runs           AxesSubplot(0.731522,0.437414;0.168478x0.130172)
# Earned Run Average       AxesSubplot(0.125,0.281207;0.168478x0.130172)
# Compelete Games       AxesSubplot(0.327174,0.281207;0.168478x0.130172)
# Shutouts              AxesSubplot(0.529348,0.281207;0.168478x0.130172)
# Saves                 AxesSubplot(0.731522,0.281207;0.168478x0.130172)
# Error                       AxesSubplot(0.125,0.125;0.168478x0.130172)
# dtype: object

# %% [markdown]
# ## Scatter plot

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
plt.figure(figsize=(20,30))
pltnumber=1

for column in X:
    if pltnumber<=15:
        ax=plt.subplot(5,3,pltnumber)
        plt.scatter(X[column],Y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Predicted Wins',fontsize=20)
    pltnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Dist plot

# %%
for col in df:
    print(skew(df[col]))
    plt.figure()
    sns.distplot(df[col])
    plt.show
# Out:
# 0.04470076997798572
# 1.1398931660307043
# 0.17413429032352498
# 0.6362644174348592
# -0.2189534077067715
# 0.12293523975827839
# 0.49025146140832154
# 0.15046085271433388
# -0.14815122992357777
# 0.4555569751737513
# 0.04341475534967941
# 0.055732557686200515
# 0.0506268488741678
# 0.6994790420153237
# 0.5370985776239573
# 0.6241798071870271
# 0.8449922672006391

# %%
df["Runs"]=np.sqrt(df["Runs"])
df.skew()
# Out:
# Predicted Wins        0.047089
# Runs                  0.968676
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Compelete Games       0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Error                 0.890132
# dtype: float64

# %%
# To find corelation using Heatmap technique
df_corr=df.corr().abs()
df_corr
plt.figure(figsize=(25,30))
sns.heatmap(df_corr,annot=True)
plt.show()

# %%
# using Select percentile method to select the best features
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import chi2

# %%
Spercentile=SelectPercentile(score_func=chi2,percentile=80)
Spercentile=Spercentile.fit(X,Y)
cols=Spercentile.get_support(indices=True)
feature=X.columns[cols]
df_scores=pd.DataFrame({'Features':X.columns,'Chi2Score':Spercentile.scores_,'pvalues':Spercentile.pvalues_})
df_scores.sort_values(by='Chi2Score',ascending=False)
print(cols)
print(feature)
# Out:
# [ 0  2  4  5  6  7  8  9 10 12 14 15]
# Index(['Runs', 'Hits', 'Triples', 'Homeruns', 'Walks', 'Strikeouts',
#        'Stolen Bases', 'Runs Allowed', 'Earned Runs', 'Compelete Games',
#        'Saves', 'Error'],
#       dtype='object')

# %%
#dropping the features which are less corelated
df=df.drop(["At Bats","Doubles","Earned Run Average","Shutouts"],axis=1)

# %%
df
# Out:
#     Predicted Wins       Runs  Hits  Triples  Homeruns  Walks  Strikeouts  \
# 0               95  26.907248  1497       42       139    383         973
# 1               83  26.381812  1349       44       156    439        1264
# 2               81  25.865034  1395       29       141    533        1157
# 3               76  24.939928  1381       27       136    404        1231
# 4               74  26.248809  1515       49       151    455        1259
# 5               93  29.849623  1480       17       232    570        1151
# 6               87  27.640550  1397       19       212    554        1227
# 7               81  26.702060  1370       20       217    418        1331
# 8               80  25.377155  1383       32       167    436        1310
# 9               78  27.349589  1495       33       161    478        1148
# 10              88  27.404379  1419       32       172    503        1233
# 11              86  27.000000  1363       26       230    486        1392
# 12              85  25.709920  1331       21       176    435        1150
# 13              76  25.612497  1379       22       198    478        1336
# 14              68  26.343880  1405       46       146    475        1119
# 15             100  25.436195  1386       39       137    506        1267
# 16              98  26.400758  1462       27       140    461        1322
# 17              97  26.248809  1341       30       171    567        1518
# 18              68  25.592968  1378       34       145    412        1299
# 19              64  25.298221  1382       27       167    496        1255
# 20              90  26.134269  1351       17       177    488        1290
# 21              83  26.514147  1363       13       177    539        1344
# 22              71  24.758837  1420       40       120    375        1150
# 23              67  23.937418  1361       18       100    471        1107
# 24              63  25.019992  1374       37       130    387        1274
# 25              92  25.826343  1346       26       187    563        1258
# 26              84  26.381812  1486       39       136    457        1159
# 27              79  26.832816  1494       48       154    490        1312
# 28              74  25.495098  1324       36       148    426        1327
# 29              68  27.147744  1479       49       186    388        1283
#
#     Stolen Bases  Runs Allowed  Earned Runs  Compelete Games  Saves  Error
# 0            104           641          601                2     56     88
# 1             70           700          653                2     45     86
# 2             86           640          584               11     38     79
# 3             68           701          643                7     37    101
# 4             83           803          746                7     35     86
# 5             88           670          609                7     34     88
# 6             63           698          652                3     48     93
# 7             44           693          646                0     43     77
# 8             87           642          604                1     60     95
# 9             71           753          694                3     40     97
# 10           101           733          680                5     45    119
# 11           121           618          572                5     39     85
# 12            52           675          630                2     46     93
# 13            69           726          677                6     45     94
# 14            78           729          664                5     28    126
# 15            69           525          478                1     62     96
# 16            98           596          532                0     54    122
# 17            95           608          546                6     48    111
# 18            84           737          682                1     40    116
# 19           134           754          700                2     35     90
# 20            51           613          557                1     50     88
# 21            57           635          577                4     41     90
# 22           112           678          638                0     35     77
# 23            69           760          698                3     44     90
# 24            88           809          749                1     35    117
# 25            59           595          553                6     47     75
# 26            93           627          597                7     41     78
# 27           132           713          659                1     44     86
# 28            82           731          655                1     41     92
# 29            97           844          799                4     36     95

# %% [markdown]
# # Model Training Using Linear Regression Without HyperParamter Tuning

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.25,random_state=21)

# %%
lm=LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lm.predict(X_test)
Y_pred_train=lm.predict(X_train)

# %%
lm.score(X_train,Y_train)
lm.score(X_test,Y_test)
# Out:
# 0.6462784795728835

# %%
import statsmodels.formula.api as smf

# %%
est=smf.ols(formula='Y~X',data=df).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     17.22
# Date:                Sun, 10 Apr 2022   Prob (F-statistic):           3.48e-07
# Time:                        11:48:08   Log-Likelihood:                -73.812
# No. Observations:                  30   AIC:                             173.6
# Df Residuals:                      17   BIC:                             191.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -15.0954     34.121     -0.442      0.664     -87.085      56.895
# X[0]           5.1372      1.803      2.850      0.011       1.334       8.941
# X[1]          -0.0058      0.024     -0.240      0.813      -0.057       0.045
# X[2]           0.0064      0.109      0.058      0.954      -0.224       0.237
# X[3]          -0.0369      0.063     -0.582      0.568      -0.171       0.097
# X[4]          -0.0131      0.021     -0.627      0.539      -0.057       0.031
# X[5]           0.0053      0.010      0.506      0.619      -0.017       0.027
# X[6]          -0.0231      0.039     -0.594      0.560      -0.105       0.059
# X[7]           0.0172      0.113      0.152      0.881      -0.222       0.256
# X[8]          -0.0974      0.117     -0.834      0.416      -0.344       0.149
# X[9]           0.6362      0.359      1.774      0.094      -0.120       1.393
# X[10]          0.5954      0.146      4.092      0.001       0.288       0.902
# X[11]         -0.0092      0.064     -0.144      0.887      -0.144       0.126
# ==============================================================================
# Omnibus:                        3.301   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                1.902
# Skew:                          -0.539   Prob(JB):                        0.386
# Kurtosis:                       3.601   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(Y_test,Y_pred)

# %%
r2
# Out:
# 0.6462784795728835

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val=cross_val_score(lm,X_train,Y_train,scoring="r2",cv=5)
cross_val
# Out:
# array([-1.03669072,  0.80382769, -0.04572205, -3.45487519,  0.88475369])

# %%
cross_val.mean()
# Out:
# -0.5697413188982281

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 4.916645835426607

# %%
mean_squared_error(Y_test,Y_pred)
# Out:
# 29.09359505513033

# %%
np.sqrt(mean_squared_error(Y_test,Y_pred))
# Out:
# 5.393847889506185

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %% [markdown]
# # Model Training Using Linear Regression With HyperParamter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
ridge=Ridge()

# %%
parameters={"alpha":[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring="r2",cv=5)

# %%
ridge_regressor.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='r2')

# %%
print(ridge_regressor.best_params_)
# Out:
# {'alpha': 5}

# %%
print(ridge_regressor.best_score_)
# Out:
# 0.6614744149485853

# %%
prediction_ridge=ridge_regressor.predict(X_test)
prediction_ridge
# Out:
# array([92.63781568, 71.57564363, 71.54581752, 73.2278037 , 78.25387806,
#        87.38570933, 71.13918236, 80.13637777])

# %%
ridge_regressor.score(X_test,Y_test)
# Out:
# 0.8245656778621684

# %%
y_pred=ridge_regressor.predict(X_test)

# %%
r2=r2_score(Y_test,y_pred)

# %%
r2
# Out:
# 0.8245656778621684

# %%
cross_val=cross_val_score(ridge_regressor,X_train,Y_train,scoring="r2",cv=5)
cross_val
# Out:
# array([0.52477268, 0.84904381, 0.35939813, 0.59069528, 0.95172565])

# %%
cross_val.mean()
# Out:
# 0.6551271093913457

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 2.92380970427344

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 14.429472995836647

# %%
np.sqrt(mean_squared_error(Y_test,y_pred))
# Out:
# 3.798614615334997

# %%
plt.scatter(Y_test,y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %% [markdown]
# # Model Training Using KNN Without HyperParamter Tuning

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.25,random_state=21)

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %%
Y_pred=knn.predict(X_test)

# %%
knn.score(X_train,Y_train)
# Out:
# 0.5904105702904888

# %%
knn.score(X_test,Y_test)
# Out:
# 0.5408510638297874

# %%
r2=r2_score(Y_test,Y_pred)
r2
# Out:
# 0.5408510638297874

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %% [markdown]
# # KNN MODEL USING HYPERPARAMETER TUNING

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.25,random_state=21)

# %%
knn=KNeighborsRegressor()

# %%
param_grid=[
    {'algorithm':['kd_tree','brute','ball_tree'],
    'leaf_size':[15,18,20],
    'n_neighbors':[3,5,7,13]
    }
]

# %%
clf=GridSearchCV(knn,param_grid,cv=3,n_jobs=-1)

# %%
clf.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid=[{'algorithm': ['kd_tree', 'brute', 'ball_tree'],
#                           'leaf_size': [15, 18, 20],
#                           'n_neighbors': [3, 5, 7, 13]}])

# %%
clf.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 15, 'n_neighbors': 7}

# %%
Y_pred=clf.predict(X_test)
Y_pred_train=clf.predict(X_train)

# %%
clf.score(X_train,Y_train)
# Out:
# 0.6391762184325784

# %%
clf.score(X_test,Y_test)
# Out:
# 0.3366726629861674

# %%
r2=r2_score(Y_test,Y_pred)
r2
# Out:
# 0.3366726629861674

# %% [markdown]
# # DECISION TREE MODEL

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=21)

# %%
dt=DecisionTreeRegressor()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(X_train,Y_train)
# Out:
# 1.0

# %%
Y_pred=dt.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred)
r2
# Out:
# -0.09118541033434657

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %% [markdown]
# # DECISION TREE WITH HYPER PARAMETER TUNING

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=21)

# %%
dt=DecisionTreeRegressor()

# %%
param_grid = {
               'max_depth': range(3,12,2),
               'min_samples_split': range(4,10,2),
               'min_samples_leaf': range(3,10,2),
              'criterion':["mse", "friedman_mse", "mae", "poisson"]}

# %%
clf=GridSearchCV(dt,param_grid,cv=5,n_jobs=-1)

# %%
clf.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'friedman_mse', 'mae', 'poisson'],
#                          'max_depth': range(3, 12, 2),
#                          'min_samples_leaf': range(3, 10, 2),
#                          'min_samples_split': range(4, 10, 2)})

# %%
clf.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 9,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8}

# %%
clf.score(X_train,Y_train)
# Out:
# 0.8306791948295883

# %%
Y_pred=clf.predict(X_test)

# %%
clf.score(X_train,Y_train)
# Out:
# 0.8306791948295883

# %%
clf.score(X_test,Y_test)
# Out:
# 0.4080323112020897

# %%
r2=r2_score(Y_test,Y_pred)
r2
# Out:
# 0.4080323112020897

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %% [markdown]
# # Modeling Using Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
X=df.drop(columns="Predicted Wins")
Y=df["Predicted Wins"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=21)

# %%
gbdt=GradientBoostingRegressor()

# %%
gbdt.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor()

# %%
Y_pred=gbdt.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred)
r2
# Out:
# 0.22845183842302796

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('actual data')
plt.ylabel('predicted data')
plt.show()

# %%
md=[lm,knn,dt,gbdt]
import pickle
filename="Baseball.pkl"
pickle.dump(md,open(filename,"wb"))

# %% [markdown]
# # Conclusion:
# 1. Conducted 4 models on BaseBall dataset namely, Linear Regression, KNN, Desicion Tree and Gradient Boosting with Hyperparameter tuning.
# 2. It comes to a conclusion that Linear Regression model is providing best score for BaseBall dataset
# 3. r2_score=0.8245656778621684
